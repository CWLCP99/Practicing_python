# %%
# Boolean data type represents two values: True or False

# %%
print(True)
print(False)
# Out:
# True
# False

# %%
# Operators: several types. 
# Assignment operators --> assing values to variables.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('Addition: ', 1+2 )
print('Substraction: ', 1-2 )
print('Multiplication: ', 1*2 )
print('Division: ', 4/2 ) # 2.0 division in python gives floating number
print('Division without remainder: ', 7//3) # 2
# Out:
# Addition:  3
# Substraction:  -1
# Multiplication:  2
# Division:  2.0
# Division without remainder:  2

# %%
print('Floating Point Number, PI', 3.14)
# Out:
# Floating Point Number, PI 3.14

# %%
# Complex numbers
print('Complex number: ', 1 + 1j)
print('Multiplying complex numbers: ',(1 + 1j) * (1 - 1j))
# Out:
# Complex number:  (1+1j)
# Multiplying complex numbers:  (2+0j)

# %%
a = 3 
b = 2 

total = a + b 
print(total)
# Out:
# 5

# %%
radius = 10 
area_of_circle = 3.14 * radius * 2
print(area_of_circle)
# Out:
# 62.800000000000004

# %%
# Comparison Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(3 > 2)     # True, because 3 is greater than 2
print(3 >= 2)    # True, because 3 is greater than 2
print(3 < 2)     # False,  because 3 is greater than 2
print(2 < 3)     # True, because 2 is less than 3
print(2 <= 3)    # True, because 2 is less than 3
print(3 == 2)    # False, because 3 is not equal to 2
print(3 != 2)    # True, because 3 is not equal to 2
print(len('mango') == len('avocado'))  # False
print(len('mango') != len('avocado'))  # True
print(len('mango') < len('avocado'))   # True
print(len('milk') != len('meat'))      # False
print(len('milk') == len('meat'))      # True
print(len('tomato') == len('potato'))  # True
print(len('python') > len('dragon'))   # False


# Comparing something gives either a True or False

print('True == True: ', True == True)
print('True == False: ', True == False)
print('False == False:', False == False)
# Out:
# True
# True
# False
# True
# True
# False
# True
# False
# True
# True
# False
# True
# True
# False
# True == True:  True
# True == False:  False
# False == False: True

# %%
print('1 is 1', 1 == 1)
print('1 is not 2', 1 != 2)
# Out:
# 1 is 1 True
# 1 is not 2 True

# %%
# Logical operators 
# Python uses keyword and, or and not for logical operators.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print (3 > 2 and 4 >3 ) # True because both have to be right. 
print (3 > 2 or 1 > 2) # true first, second false, but we are using "or" operator. 
print(not 3>2) # False because 3 is bigger than 2 indeed.
# Out:
# True
# True
# False

# %%
# Exercises Day 3

# %%
# Declare your age as integer variable 
age = int(27)
print(type(age))
print(age)
# Out:
# <class 'int'>
# 27

# %%
# Declare your height as a float variable 
height = float(1.88)
print(height)
print(type(height))
# Out:
# 1.88
# <class 'float'>

# %%
# Write a script that prompts the user to enter base and height of the triangle and calculate the area of this triangle (area = 0.5 x b x h)

base = input('tell me the base')
height = input('tell me the height')
print(base, height)
area_triangle = 0.5 * float(base) * float(height)
print(int(area_triangle))
# Out:
# 20 20
# 200

# %%
# Write a script that prompts the user to enter side a, side b, side c of the triangle. Calculate the perimeter of the triangle (perimeter = a + b + c)
side_a = input('input side a')
side_b = input('input side b')
side_c = input('input side c')

print(type(side_c))

perimeter = int(side_a) + int(side_b) + int(side_c)

print(perimeter)
# Out:
# <class 'str'>
# 30

# %%
# Declaring values and organizing them together
num_one = 3
num_two = 4

# Arithmetic operations
total = num_one + num_two
print(total)
# Out:
# 7
